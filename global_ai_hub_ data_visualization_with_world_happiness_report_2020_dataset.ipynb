# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv("world-happiness-report.csv")
data
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
sns.set(rc=('figure.figsize':(5,5)))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country name                      1949 non-null   object
#  1   year                              1949 non-null   int64
#  2   Life Ladder                       1949 non-null   float64
#  3   Log GDP per capita                1913 non-null   float64
#  4   Social support                    1936 non-null   float64
#  5   Healthy life expectancy at birth  1894 non-null   float64
#  6   Freedom to make life choices      1917 non-null   float64
#  7   Generosity                        1860 non-null   float64
#  8   Perceptions of corruption         1839 non-null   float64
#  9   Positive affect                   1927 non-null   float64
#  10  Negative affect                   1933 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# ...

# %%
data["Country name"].value_counts()
# Out:
# Zimbabwe        15
# South Africa    15
# Tanzania        15
# Denmark         15
# Tajikistan      15
#                 ..
# Maldives         1
# Suriname         1
# Cuba             1
# Oman             1
# Guyana           1
# Name: Country name, Length: 166, dtype: int64

# %%
data.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1949.000000  1949.000000         1913.000000     1936.000000
# mean   2013.216008     5.466705            9.368453        0.812552
# std       4.166828     1.115711            1.154084        0.118482
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.640000            8.464000        0.749750
# 50%    2013.000000     5.386000            9.460000        0.835500
# 75%    2017.000000     6.283000           10.353000        0.905000
# max    2020.000000     8.019000           11.648000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359374                      0.742558
# std                            7.510245                      0.142093
# min                           32.300000                      0.258000
# ...

# %%
data.describe().T
# Out:
#                                    count         mean       std       min  \
# year                              1949.0  2013.216008  4.166828  2005.000
# Life Ladder                       1949.0     5.466705  1.115711     2.375
# Log GDP per capita                1913.0     9.368453  1.154084     6.635
# Social support                    1936.0     0.812552  0.118482     0.290
# Healthy life expectancy at birth  1894.0    63.359374  7.510245    32.300
# Freedom to make life choices      1917.0     0.742558  0.142093     0.258
# Generosity                        1860.0     0.000103  0.162215    -0.335
# Perceptions of corruption         1839.0     0.747125  0.186789     0.035
# Positive affect                   1927.0     0.710003  0.107100     0.322
# Negative affect                   1933.0     0.268544  0.085168     0.083
#
#                                          25%        50%       75%       max
# year                              2010.00000  2013.0000  2017.000  2020.000
# ...

# %%
from os import mkdir#make direction

# %%
try:
    mkdir("Plots")
except:
    pass
mypath="Plots"

# %%
cols=data.select_dtypes(exclude="object").columns#take out the type what name is 'object'
cols
# Out:
# Index(['year', 'Life Ladder', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect'],
#       dtype='object')

# %%
x_axis=0
y_axis=0
# Out:
# year
# Life Ladder
# Log GDP per capita
# Social support
# Healthy life expectancy at birth
# Freedom to make life choices
# Generosity
# Perceptions of corruption
# Positive affect
# Negative affect

# %%
from IPython.core.pylabtools import figsize
f,axes=plt.subplots(5,2,figsize=(15,20))#Making subplot name of f and axes, 5 Rows and 2 columns
f.tight_layout(pad=8)#Space between two subplots it have 8 pad
f.suptitle('Distrubution before preprocessing')#Upper Title

x_axis=0
y_axis=0

for col in cols:
    sns.histplot(data=data,x=col,kde=True,ax=axes[x_axis,y_axis])
    axes[x_axis,y_axis].set_xlabel(col.title())
    axes[x_axis,y_axis].set_ylabel(col.title())
    axes[x_axis,y_axis].set_title(f"{col.title()} Count")

    if y_axis==1:
        y_axis=0
        x_axis+=1
    else:
        y_axis+=1
        
plt.savefig("Plots/Histogram.png")
plt.show()

# %%
f,axes=plt.subplots(5,2,figsize=(15,20))#Making subplot name of f and axes, 5 Rows and 2 columns
f.tight_layout(pad=8)#Space between two subplots it have 8 pad
f.suptitle('Distrubution before preprocessing')#Upper Title

x_axis=0
y_axis=0

for col in cols:
    sns.boxplot(data=data,x=col,ax=axes[x_axis,y_axis])
    axes[x_axis,y_axis].set_xlabel(col)
    axes[x_axis,y_axis].set_ylabel("Count")
    axes[x_axis,y_axis].set_title(f"{col.title()} Box Count")

    if y_axis==1:
        y_axis=0
        x_axis+=1
    else:
        y_axis+=1
        
plt.savefig("Plots/Boxplot.png")
plt.show()

# %%
year_group=data.groupby("year").sum()
year_group
# Out:
#       Life Ladder  Log GDP per capita  Social support  \
# year
# 2005      174.049             273.204          24.230
# 2006      462.524             795.897          74.387
# 2007      552.664             935.641          80.777
# 2008      596.036            1008.400          86.283
# 2009      622.174            1046.810          92.555
# 2010      681.604            1155.443          99.824
# 2011      791.916            1346.593         116.406
# 2012      773.013            1314.683         114.887
# 2013      739.055            1274.760         110.498
# 2014      781.408            1330.678         114.401
# 2015      772.777            1315.491         113.345
# 2016      766.726            1307.019         115.289
# 2017      802.680            1371.967         117.551
# 2018      780.921            1279.317         115.353
# 2019      802.205            1307.830         117.618
# 2020      554.857             858.117          79.697
#
# ...

# %%
year_group["Positive affect"].plot()
plt.savefig("Plots/PositiveAffectPlot.png")

# %%
year_group["Negative affect"].plot()
plt.savefig("Plots/NegativeAffectPlot.png")

# %%
ax1=sns.barplot(x=year_group.index,y=year_group['Social support'].values)
ax1.tick_params(axis="x",rotation=90)
plt.savefig("Plots/SocialSupportBarplot.png")

# %%
sns.set(rc={'figure.figsize':(15,10)})
plt.title("Correlation Matrix")
sns.heatmap(data.corr(),annot=True)
plt.savefig("Plots/CorrelationMatrixHeatmap.png")

# %%
sns.jointplot(data=data,x="year",y="Social support")
sns.jointplot(data=data,x="Life Ladder",y="Social support")

# %%
import os 
from os import listdir,mkdir
from os.path import isfile,join

# %%
all_files=os.listdir("Plots/")
report=[f"Plots/{file}" for file in all_files]
print(report)
# Out:
# ['Plots/Boxplot.png', 'Plots/CorrelationMatrixHeatmap.png', 'Plots/Histogram.png', 'Plots/NegativeAffectPlot.png', 'Plots/PositiveAffectPlot.png', 'Plots/SocialSupportBarplot.png']

# %%
# !pip install FPDF
# Out:
# ...
#   Created wheel for FPDF: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40722 sha256=3ee80b98268c09fc07bff18c6c102bb0ed9a4f91bba35216d12a2836fcbf3092
#   Stored in directory: c:\users\muhammet\appdata\local\pip\cache\wheels\44\35\8b\86ce00cec7e4d13c5f189680ae0fa82f919bedc066c2cddae9
# Successfully built FPDF
# ...
# WARNING: Ignoring invalid distribution -ip (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\anaconda3\lib\site-packages)

# %%
from fpdf import FPDF

# %%
WIDTH=210
HEIGHT=297

# %%
pdf=FPDF()
pdf.set_font("Arial","B",56)

pdf.add_page()
pdf.cell(180,20,txt='REPORT',align='C')

for report in report:
    pdf.add_page()
    
    pdf.set_font("Arial","B",24)
    pdf.cell(180,20,txt=report,align='C')
    
    pdf.image(report,5,30,WIDTH-5)

pdf.output("Countries_Report.pdf","F")
# Out:
# ''
